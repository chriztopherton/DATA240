# %%
import pandas as pd
import numpy as np

# %%
final = pd.read_csv("final_df.csv")
final
# Out:
#       Unnamed: 0     id project_code          pq_num po_so_num asndn_num  \
# 0              3     15   108-VN-T01  Pre-PQ Process   SCMS-78    ASN-50
# 1              4     16   108-VN-T01  Pre-PQ Process   SCMS-81    ASN-55
# 2              6     44   110-ZM-T01  Pre-PQ Process  SCMS-139   ASN-130
# 3              7     45   109-TZ-T01  Pre-PQ Process  SCMS-140    ASN-94
# 4              8     46   112-NG-T01  Pre-PQ Process  SCMS-156    ASN-93
# ...          ...    ...          ...             ...       ...       ...
# 5419       10316  86815   151-NG-T30       FPQ-16313  SO-51420   DN-4279
# 5420       10317  86816   151-NG-T30       FPQ-16313  SO-51440   DN-4282
# 5421       10320  86819   104-CI-T30       FPQ-15259  SO-50102   DN-4313
# 5422       10322  86822   200-ZW-T30       FPQ-16523  SO-51680   DN-4334
# 5423       10323  86823   103-ZW-T30       FPQ-15197  SO-50022   DN-4336
#
#             country managed_by  fulfill_via vendor_inco_term  ...  \
# ...

# %%
final = pd.read_csv("final_df.csv", index_col = "Unnamed: 0")
final
# Out:
#           id project_code          pq_num po_so_num asndn_num        country  \
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78    ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81    ASN-55        Vietnam
# 6         44   110-ZM-T01  Pre-PQ Process  SCMS-139   ASN-130         Zambia
# 7         45   109-TZ-T01  Pre-PQ Process  SCMS-140    ASN-94       Tanzania
# 8         46   112-NG-T01  Pre-PQ Process  SCMS-156    ASN-93        Nigeria
# ...      ...          ...             ...       ...       ...            ...
# 10316  86815   151-NG-T30       FPQ-16313  SO-51420   DN-4279        Nigeria
# 10317  86816   151-NG-T30       FPQ-16313  SO-51440   DN-4282        Nigeria
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102   DN-4313  Côte d'Ivoire
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680   DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022   DN-4336       Zimbabwe
#
# ...

# %%
final.columns
# Out:
# Index(['id', 'project_code', 'pq_num', 'po_so_num', 'asndn_num', 'country',
#        'managed_by', 'fulfill_via', 'vendor_inco_term', 'shipment_mode',
#        'pq_first_sent_to_client_date', 'po_sent_to_vendor_date',
#        'scheduled_delivery_date', 'delivered_to_client_date',
#        'delivery_recorded_date', 'product_group', 'sub_classification',
#        'vendor', 'moleculetest_type', 'brand', 'dosage', 'dosage_form',
#        'unit_of_measure_per_pack', 'line_item_quantity', 'line_item_value',
#        'pack_price', 'unit_price', 'manufacturing_site',
#        'first_line_designation', 'weight_kilograms', 'freight_cost_usd',
#        'line_item_insurance_usd', 'po_sent_to_vendor_date_year',
#        'scheduled_delivery_date_year', 'delivered_to_client_date_year',
#        'delivery_recorded_date_year', 'pq_first_sent_to_client_date_year',
#        'moleculetest_type_processed', 'cluster_labels', 'active_ingredients',
# ...

# %%
final['description_type'] = final['description_type'].fillna(pd.NA).replace({pd.NA: None})
final.tail()
# Out:
#           id project_code     pq_num po_so_num asndn_num        country  \
# 10316  86815   151-NG-T30  FPQ-16313  SO-51420   DN-4279        Nigeria
# 10317  86816   151-NG-T30  FPQ-16313  SO-51440   DN-4282        Nigeria
# 10320  86819   104-CI-T30  FPQ-15259  SO-50102   DN-4313  Côte d'Ivoire
# 10322  86822   200-ZW-T30  FPQ-16523  SO-51680   DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30  FPQ-15197  SO-50022   DN-4336       Zimbabwe
#
#       managed_by fulfill_via vendor_inco_term shipment_mode  ...  \
# 10316   PMO - US    From RDC   N/A - From RDC   Air Charter  ...
# 10317   PMO - US    From RDC   N/A - From RDC           Air  ...
# 10320   PMO - US    From RDC   N/A - From RDC         Truck  ...
# 10322   PMO - US    From RDC   N/A - From RDC         Truck  ...
# 10323   PMO - US    From RDC   N/A - From RDC         Truck  ...
#
#       description_type manufacturing_location manufacturers  \
# 10316             None          Telangana, IN     Aurobindo
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
final.tail()
# Out:
#           id project_code     pq_num po_so_num asndn_num        country  \
# 10316  86815   151-NG-T30  FPQ-16313  SO-51420   DN-4279        Nigeria
# 10317  86816   151-NG-T30  FPQ-16313  SO-51440   DN-4282        Nigeria
# 10320  86819   104-CI-T30  FPQ-15259  SO-50102   DN-4313  Côte d'Ivoire
# 10322  86822   200-ZW-T30  FPQ-16523  SO-51680   DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30  FPQ-15197  SO-50022   DN-4336       Zimbabwe
#
#       managed_by fulfill_via vendor_inco_term shipment_mode  \
# 10316   PMO - US    From RDC   N/A - From RDC   Air Charter
# 10317   PMO - US    From RDC   N/A - From RDC           Air
# 10320   PMO - US    From RDC   N/A - From RDC         Truck
# 10322   PMO - US    From RDC   N/A - From RDC         Truck
# 10323   PMO - US    From RDC   N/A - From RDC         Truck
#
#       pq_first_sent_to_client_date po_sent_to_vendor_date  \
# 10316                   2015-05-04                    NaN
# ...

# %%
#final.iloc[[0], [18, 19, 20, 21, 22, 23]]
final.iloc[:, : 20].tail()
# Out:
#           id project_code     pq_num po_so_num asndn_num        country  \
# 10316  86815   151-NG-T30  FPQ-16313  SO-51420   DN-4279        Nigeria
# 10317  86816   151-NG-T30  FPQ-16313  SO-51440   DN-4282        Nigeria
# 10320  86819   104-CI-T30  FPQ-15259  SO-50102   DN-4313  Côte d'Ivoire
# 10322  86822   200-ZW-T30  FPQ-16523  SO-51680   DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30  FPQ-15197  SO-50022   DN-4336       Zimbabwe
#
#       managed_by fulfill_via vendor_inco_term shipment_mode  \
# 10316   PMO - US    From RDC   N/A - From RDC   Air Charter
# 10317   PMO - US    From RDC   N/A - From RDC           Air
# 10320   PMO - US    From RDC   N/A - From RDC         Truck
# 10322   PMO - US    From RDC   N/A - From RDC         Truck
# 10323   PMO - US    From RDC   N/A - From RDC         Truck
#
#       pq_first_sent_to_client_date po_sent_to_vendor_date  \
# 10316                   2015-05-04                    NaN
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5424 entries, 3 to 10323
# Data columns (total 50 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 5424 non-null   int64
#  1   project_code                       5424 non-null   object
#  2   pq_num                             5424 non-null   object
#  3   po_so_num                          5424 non-null   object
#  4   asndn_num                          5424 non-null   object
#  5   country                            5424 non-null   object
#  6   managed_by                         5424 non-null   object
#  7   fulfill_via                        5424 non-null   object
#  8   vendor_inco_term                   5424 non-null   object
#  9   shipment_mode                      5233 non-null   object
#  10  pq_first_sent_to_client_date       4035 non-null   object
# ...

# %%
# number of unique counts in categorical columns of object data type
print('The number of unique counts in each column:')
print()
for cols in final.columns[0:]:
    print(cols,"=", len(final[cols].unique()))
# Out:
# The number of unique counts in each column:
#
# id = 5424
# project_code = 105
# pq_num = 743
# po_so_num = 3407
# asndn_num = 3623
# country = 38
# managed_by = 2
# fulfill_via = 2
# vendor_inco_term = 7
# shipment_mode = 5
# pq_first_sent_to_client_date = 527
# po_sent_to_vendor_date = 502
# scheduled_delivery_date = 1483
# delivered_to_client_date = 1604
# delivery_recorded_date = 1533
# product_group = 5
# sub_classification = 6
# vendor = 36
# moleculetest_type = 46
# brand = 26
# dosage = 49
# dosage_form = 16
# unit_of_measure_per_pack = 14
# line_item_quantity = 2849
# line_item_value = 4893
# pack_price = 833
# unit_price = 85
# manufacturing_site = 57
# first_line_designation = 2
# weight_kilograms = 1617
# freight_cost_usd = 2819
# line_item_insurance_usd = 3581
# po_sent_to_vendor_date_year = 11
# scheduled_delivery_date_year = 10
# delivered_to_client_date_year = 10
# delivery_recorded_date_year = 10
# pq_first_sent_to_client_date_year = 8
# ...
